# %% [markdown]
# <a href="https://colab.research.google.com/github/geppy29/fa3-comsci-q4/blob/main/fa3prog2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score = float(input("Enter your exam score: "))

# %%
if score > 100:
      print("Unidentifiable")

# %%
if score > 74:
    print("Passed!")
else:
    print("Failed!")
