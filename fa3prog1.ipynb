# %% [markdown]
# <a href="https://colab.research.google.com/github/geppy29/fa3-comsci-q4/blob/main/fa3prog1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter name: ")

# %%
num1 = float(input("Enter age: "))

# %%
course = input("Enter course: ")

# %%
print(f"""
--- Student Information Display ---
Name:   {name}
Age:    {num1}
Course: {course}
-----------------------
""")
